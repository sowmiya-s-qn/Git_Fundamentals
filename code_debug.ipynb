# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm=ChatOpenAI(model="gpt-4o-mini", temperature=0)

code_query="""
Fix the error and explain it:

for i in range(5)
    print(i)
"""
print(llm.invoke(code_query))
# Out:
# content='The error in your code is a missing colon (`:`) at the end of the `for` statement. In Python, a colon is required to indicate the start of the block of code that will be executed for each iteration of the loop.\n\nHere is the corrected code:\n\n```python\nfor i in range(5):\n    print(i)\n```\n\n### Explanation:\n- The `for` loop iterates over a sequence (in this case, the numbers generated by `range(5)`, which are 0, 1, 2, 3, and 4).\n- The colon (`:`) at the end of the `for` statement tells Python that the following indented block of code is part of the loop.\n- The `print(i)` statement is indented, which means it is executed for each value of `i` in the loop. \n\nWith the correction, the code will print the numbers 0 through 4, each on a new line.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 199, 'prompt_tokens': 26, 'total_tokens': 225, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reaso
# ...
