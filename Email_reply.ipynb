# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(temperature=0.5)

# %%
from langchain.prompts import PromptTemplate

prompt = PromptTemplate(
    input_variables=["email"],
    template="""
Write a polite and professional reply to this email:

{email}
"""
)

# %%
from langchain.chains import LLMChain

chain = LLMChain(llm=llm, prompt=prompt)

# %%
print(chain.run("My order is delayed. I am unhappy."))
# Out:
# /tmp/ipykernel_15321/2555209917.py:1: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   print(chain.run("My order is delayed. I am unhappy."))
# Dear [Customer],
#
# Thank you for bringing this to our attention. We apologize for the delay in your order and understand your frustration. Our team is working diligently to resolve the issue and expedite the delivery of your order.
#
# We appreciate your patience and understanding during this time. If you have any further questions or concerns, please do not hesitate to contact us.
#
# Thank you for your continued support.
#
# Sincerely,
# [Your Name]
# [Your Title]
# [Company Name]
